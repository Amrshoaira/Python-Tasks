# %% [markdown]
# <a href="https://colab.research.google.com/github/Amrshoaira/Python-Tasks/blob/main/Task_3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
contacts = {"Amor":"011112233", "Omar":"0122233344", "Mohamed":"0155566677"}

print("Contacts available:")
print(contacts.keys())
search_name = input("\nEnter the name: ")

if search_name in contacts:
    print(f"{search_name}'s phone number is: {contacts[search_name]}")
else:
    print("Sorry, that contact was not found.")
# Out:
# Contacts available:
# dict_keys(['Amor', 'Omar', 'Mohamed'])
#
# Enter the name: Omar
# Omar's phone number is: 0122233344
