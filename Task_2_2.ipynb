# %% [markdown]
# <a href="https://colab.research.google.com/github/Amrshoaira/Python-Tasks/blob/main/Task_2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
divided_by_3 = []
for num in range(1,21):
    if num % 3 == 0:
        print(f"{num} is divisible by 3")
        divided_by_3.append(num) #append numbers to a list
print("Numbers divisible by 3:", divided_by_3)
